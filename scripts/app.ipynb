# %%
import pandas as pd
import numpy as np
from nltk import word_tokenize
from tqdm import tqdm
import time

#for Requests
from bs4 import BeautifulSoup
import requests as re

# %% [markdown]
# ### Note:
#
# It seems the we can't do read_csv from google drive for a large file either. So, I have added a .gitignore file on the repo. That means we can have the 180mb data file on our /data folder, and when we push the repo, the .csv file won't be included. That's how we can push and pull without a probelem.
#
# PS: MAKE sure to have the labeled_lyrics_cleaned.csv file to your data folder after cloning this repo.

# %%
# 150_k_dataset
df_150k = pd.read_csv('../data/labeled_lyrics_cleaned.csv')

# %%
df_150k.head()
# Out:
#    Unnamed: 0        artist  \
# 0           0  Elijah Blake
# 1           1  Elijah Blake
# 2           2  Elijah Blake
# 3           3  Elijah Blake
# 4           4  Elijah Blake
#
#                                                  seq                song  \
# 0  No, no\r\nI ain't ever trapped out the bando\r...            Everyday
# 1  The drinks go down and smoke goes up, I feel m...    Live Till We Die
# 2  She don't live on planet Earth no more\r\nShe ...       The Otherside
# 3  Trippin' off that Grigio, mobbin', lights low\...               Pinot
# 4  I see a midnight panther, so gallant and so br...  Shadows & Diamonds
#
#    label
# 0  0.626
# 1  0.630
# 2  0.240
# 3  0.536
# 4  0.371

# %%
artist = list(df_150k['artist'].unique())

# %%
def add_dash(input_str):
    input_str = input_str.replace("&", "and")
    tokenize = word_tokenize(input_str)
    return "-".join(tokenize)

input_str = '''Shadows & Diamonds'''
print(add_dash(input_str))
# Out:
# Shadows-and-Diamonds

# %%
df_150k['ar_dash'] = df_150k['artist'].apply(add_dash)

# %%
df_150k['title_dash']  = df_150k['song'].apply(add_dash)

# %%
df_150k['song_path'] = df_150k['ar_dash'] + '-' + df_150k["title_dash"] + "-lyrics"

# %%
base = 'https://genius.com/'
df_150k['url'] = base + df_150k['song_path']

# %%
df_150k.iloc[90:100]
# Out:
#     Unnamed: 0                    artist  \
# 90          90           Eliza Doolittle
# 91          91           Eliza Doolittle
# 92          92            Eliza Gilkyson
# 93          93            Eliza Gilkyson
# 94          94  Elizabeth & the Catapult
# 95          95  Elizabeth & the Catapult
# 96          96  Elizabeth & the Catapult
# 97          97  Elizabeth & the Catapult
# 98          98  Elizabeth & the Catapult
# 99          99          Elizabeth Cotten
#
#                                                   seq  \
# 90  I'm wishing away\r\nEveryday, everyday that we...
# 91  What a waste of time\r\nPrecious little time\r...
# 92  Many years ago he looked out through a glass-l...
# 93  Beautiful world circling infinitely\r\nFragmen...
# 94  This is the first time dreaming in these hues\...
# 95  Oh, Apathy\r\nDon't patronize me\r\nI wasn't s...
# 96  When I was girl I dreamed of my twin\r\nShe sh...
# 97  Everybody knows that the dice are loaded\r\nEv...
# ...

# %%
df_150kk = df_150k.iloc[0:100]

# %%
df_150kk
# Out:
#     Unnamed: 0                    artist  \
# 0            0              Elijah Blake
# 1            1              Elijah Blake
# 2            2              Elijah Blake
# 3            3              Elijah Blake
# 4            4              Elijah Blake
# ..         ...                       ...
# 95          95  Elizabeth & the Catapult
# 96          96  Elizabeth & the Catapult
# 97          97  Elizabeth & the Catapult
# 98          98  Elizabeth & the Catapult
# 99          99          Elizabeth Cotten
#
#                                                   seq  \
# 0   No, no\r\nI ain't ever trapped out the bando\r...
# 1   The drinks go down and smoke goes up, I feel m...
# 2   She don't live on planet Earth no more\r\nShe ...
# 3   Trippin' off that Grigio, mobbin', lights low\...
# 4   I see a midnight panther, so gallant and so br...
# ..                                                ...
# 95  Oh, Apathy\r\nDon't patronize me\r\nI wasn't s...
# ...

# %%
df_150kk['genre'].value_counts()
# Out:
# Pop          68
# No_genre     20
# Rap           5
# R&B           4
# Rock          1
# Non-Music     1
# Country       1
# Name: genre, dtype: int64

# %%
df_150kk['genre'].value_counts()
# Out:
# Pop          72
# No_genre     15
# R&B           5
# Rap           5
# Rock          1
# Non-Music     1
# Country       1
# Name: genre, dtype: int64

# %%
# df_150kk['genre'] = df_150kk['url'].apply(get_genre)
# Out:
# C:\Users\dip2l\AppData\Local\Temp\ipykernel_2104\3531961340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_150kk['genre'] = df_150kk['url'].apply(get_genre)

# %%
df_150kk.to_csv('hun.csv', index=False)

# %%
for i in dff['url']:
    print(i)
    print(get_genre(i))
# Out:
# https://genius.com/Julia-Holter-Try-To-Make-Yourself-a-Work-of-Art-lyrics
# Pop
# https://genius.com/Julia-Holter-Feel-You-lyrics
# Pop
# https://genius.com/Julia-Holter-Everytime-Boots-lyrics
# Pop
# https://genius.com/Julia-Holter-Have-You-in-My-Wilderness-lyrics
# Pop
# https://genius.com/Julia-Holter-How-Long-?-lyrics
# No_genre

# %%
def get_genre(url):

    HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5)'
                          'AppleWebKit/537.36 (KHTML, like Gecko)'
                          'Chrome/45.0.2454.101 Safari/537.36'),
                          'referer': 'http://stats.nba.com/scores/'}
    
    source = re.get(url).text

    #soup object 
    soup = BeautifulSoup(source, 'lxml')

    #get the Genre class 
    tag_div = soup.find('div', class_='SongTags__Container-xixwg3-1 bZsZHM')
    
    #get the first genre from genre class
    try:
        tag_name = tag_div.a.text
        return tag_name
    except:
        return "No_genre";

# %%
df_03 = ""

# %%
df_03 = df_01.combine_first(df_02)

# %%
len(df_03)
# Out:
# 15834

# %%
df_04 = df_150k.iloc[(7917+7917):(7917+7917+10)]

# %%
df_03 = df_03.combine_first(df_04)

# %%
start_index = 0
end_index = 0 
gap = 8300

for i in range(18):
    start_index +=  end_index;
    end_index += gap
    print("DF:", i, "start: ", start_index, "end: ", end_index)
# Out:
# DF: 0 start:  0 end:  8300
# DF: 1 start:  8300 end:  16600
# DF: 2 start:  24900 end:  24900
# DF: 3 start:  49800 end:  33200
# DF: 4 start:  83000 end:  41500
# DF: 5 start:  124500 end:  49800
# DF: 6 start:  174300 end:  58100
# DF: 7 start:  232400 end:  66400
# DF: 8 start:  298800 end:  74700
# DF: 9 start:  373500 end:  83000
# DF: 10 start:  456500 end:  91300
# DF: 11 start:  547800 end:  99600
# DF: 12 start:  647400 end:  107900
# DF: 13 start:  755300 end:  116200
# DF: 14 start:  871500 end:  124500
# DF: 15 start:  996000 end:  132800
# DF: 16 start:  1128800 end:  141100
# DF: 17 start:  1269900 end:  149400

# %%
df_150k.to_csv('labeled_lyrics_cleaned_w_url.csv', index=False)

# %%
df_150k.head()
# Out:
#    Unnamed: 0        artist  \
# 0           0  Elijah Blake
# 1           1  Elijah Blake
# 2           2  Elijah Blake
# 3           3  Elijah Blake
# 4           4  Elijah Blake
#
#                                                  seq                song  \
# 0  No, no\r\nI ain't ever trapped out the bando\r...            Everyday
# 1  The drinks go down and smoke goes up, I feel m...    Live Till We Die
# 2  She don't live on planet Earth no more\r\nShe ...       The Otherside
# 3  Trippin' off that Grigio, mobbin', lights low\...               Pinot
# 4  I see a midnight panther, so gallant and so br...  Shadows & Diamonds
#
#    label       ar_dash            title_dash  \
# 0  0.626  Elijah-Blake              Everyday
# 1  0.630  Elijah-Blake      Live-Till-We-Die
# 2  0.240  Elijah-Blake         The-Otherside
# 3  0.536  Elijah-Blake                 Pinot
# 4  0.371  Elijah-Blake  Shadows-and-Diamonds
#
#                                   song_path  \
# ...

# %%
df_00 = df_150k.iloc[0:8300]

# %%
#df_00['genre'] = df_00['url'].apply(get_genre)
# Out:
# C:\Users\dip2l\AppData\Local\Temp\ipykernel_2104\1926675922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_00['genre'] = df_00['url'].apply(get_genre)

# %%
df_00.head()
# Out:
#    Unnamed: 0        artist  \
# 0           0  Elijah Blake
# 1           1  Elijah Blake
# 2           2  Elijah Blake
# 3           3  Elijah Blake
# 4           4  Elijah Blake
#
#                                                  seq                song  \
# 0  No, no\r\nI ain't ever trapped out the bando\r...            Everyday
# 1  The drinks go down and smoke goes up, I feel m...    Live Till We Die
# 2  She don't live on planet Earth no more\r\nShe ...       The Otherside
# 3  Trippin' off that Grigio, mobbin', lights low\...               Pinot
# 4  I see a midnight panther, so gallant and so br...  Shadows & Diamonds
#
#    label       ar_dash            title_dash  \
# 0  0.626  Elijah-Blake              Everyday
# 1  0.630  Elijah-Blake      Live-Till-We-Die
# 2  0.240  Elijah-Blake         The-Otherside
# 3  0.536  Elijah-Blake                 Pinot
# 4  0.371  Elijah-Blake  Shadows-and-Diamonds
#
#                                   song_path  \
# ...

# %%
df_00['genre'].value_counts()
# Out:
# No_genre     3049
# Pop          3048
# Rock         1281
# Rap           485
# R&B           228
# Country       203
# Non-Music       6
# Name: genre, dtype: int64

# %%
df_00.to_csv('labeled_lyrics_0_8000.csv', index=False)

# %%
new_df = df_150k[8301:158353]

# %%
df_sh = new_df.reindex(np.random.permutation(new_df.index))
df_sh.reset_index(inplace=True, drop=True)

# %%
df_sh.iloc[0:10]
# Out:
#    Unnamed: 0             artist  \
# 0       74321      Judith Durham
# 1       63297       Kevin Fowler
# 2       43925         The Damned
# 3       14600     Rebecca Martin
# 4       47492        Fatboy Slim
# 5       61209            Emblem3
# 6      113948    Kacey Musgraves
# 7       29660  Far East Movement
# 8      133296    Ella Fitzgerald
# 9       65765         Bear's Den
#
#                                                  seq                    song  \
# 0  My heart is sad and lonely\r\nFor you I sigh, ...           Body and Soul
# 1  I ain't gettin' up early, ain't sittin' outsid...         Beer Season [#]
# 2  [Chorus]\r\nObscene\r\nThe scene\r\nThe dream\...                 Obscene
# 3  On her way home she starts to cry\r\nThis feel...                Learning
# 4  Watch that...\r\nBut it is hip though the way ...  The Sound of Milwaukee
# 5  You called me said he broke your heart again\n...                      XO
# ...

# %%
len(df_00) + len(df_sh)
# Out:
# 158352

# %% [markdown]
# ## DF_01

# %%
df_01 = df_sh.iloc[0:8300]
df_01.head()
# Out:
#    Unnamed: 0          artist  \
# 0       74321   Judith Durham
# 1       63297    Kevin Fowler
# 2       43925      The Damned
# 3       14600  Rebecca Martin
# 4       47492     Fatboy Slim
#
#                                                  seq                    song  \
# 0  My heart is sad and lonely\r\nFor you I sigh, ...           Body and Soul
# 1  I ain't gettin' up early, ain't sittin' outsid...         Beer Season [#]
# 2  [Chorus]\r\nObscene\r\nThe scene\r\nThe dream\...                 Obscene
# 3  On her way home she starts to cry\r\nThis feel...                Learning
# 4  Watch that...\r\nBut it is hip though the way ...  The Sound of Milwaukee
#
#     label         ar_dash              title_dash  \
# 0  0.0796   Judith-Durham           Body-and-Soul
# 1  0.9020    Kevin-Fowler       Beer-Season-[-#-]
# 2  0.3930      The-Damned                 Obscene
# 3  0.1480  Rebecca-Martin                Learning
# 4  0.2080     Fatboy-Slim  The-Sound-of-Milwaukee
#
# ...

# %%
#df_00['genre'] = df_00['url'].apply(get_genre)
