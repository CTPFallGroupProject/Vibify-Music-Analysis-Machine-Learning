# %%
import pandas as pd
from nltk import word_tokenize
from tqdm import tqdm
import time

#for Requests
from bs4 import BeautifulSoup
import requests as re

# %% [markdown]
# ### Note:
#
# It seems the we can't do read_csv from google drive for a large file either. So, I have added a .gitignore file on the repo. That means we can have the 180mb data file on our /data folder, and when we push the repo, the .csv file won't be included. That's how we can push and pull without a probelem.
#
# PS: MAKE sure to have the labeled_lyrics_cleaned.csv file to your data folder after cloning this repo.

# %%
# 150_k_dataset
df_150k = pd.read_csv('../data/labeled_lyrics_cleaned.csv')

# %%
df_150k.head()
# Out:
#    Unnamed: 0        artist  \
# 0           0  Elijah Blake
# 1           1  Elijah Blake
# 2           2  Elijah Blake
# 3           3  Elijah Blake
# 4           4  Elijah Blake
#
#                                                  seq                song  \
# 0  No, no\r\nI ain't ever trapped out the bando\r...            Everyday
# 1  The drinks go down and smoke goes up, I feel m...    Live Till We Die
# 2  She don't live on planet Earth no more\r\nShe ...       The Otherside
# 3  Trippin' off that Grigio, mobbin', lights low\...               Pinot
# 4  I see a midnight panther, so gallant and so br...  Shadows & Diamonds
#
#    label
# 0  0.626
# 1  0.630
# 2  0.240
# 3  0.536
# 4  0.371

# %%
artist = list(df_150k['artist'].unique())

# %%
def add_dash(input_str):
    input_str = input_str.replace("&", "and")
    tokenize = word_tokenize(input_str)
    return "-".join(tokenize)

input_str = '''Shadows & Diamonds'''
print(add_dash(input_str))
# Out:
# Shadows-and-Diamonds

# %%
df_150k['ar_dash'] = df_150k['artist'].apply(add_dash)

# %%
df_150k['title_dash']  = df_150k['song'].apply(add_dash)

# %%
df_150k['song_path'] = df_150k['ar_dash'] + '-' + df_150k["title_dash"] + "-lyrics"

# %%
base = 'https://genius.com/'
df_150k['url'] = base + df_150k['song_path']

# %%
df_150k.iloc[90:100]
# Out:
#     Unnamed: 0                    artist  \
# 90          90           Eliza Doolittle
# 91          91           Eliza Doolittle
# 92          92            Eliza Gilkyson
# 93          93            Eliza Gilkyson
# 94          94  Elizabeth & the Catapult
# 95          95  Elizabeth & the Catapult
# 96          96  Elizabeth & the Catapult
# 97          97  Elizabeth & the Catapult
# 98          98  Elizabeth & the Catapult
# 99          99          Elizabeth Cotten
#
#                                                   seq  \
# 90  I'm wishing away\r\nEveryday, everyday that we...
# 91  What a waste of time\r\nPrecious little time\r...
# 92  Many years ago he looked out through a glass-l...
# 93  Beautiful world circling infinitely\r\nFragmen...
# 94  This is the first time dreaming in these hues\...
# 95  Oh, Apathy\r\nDon't patronize me\r\nI wasn't s...
# 96  When I was girl I dreamed of my twin\r\nShe sh...
# 97  Everybody knows that the dice are loaded\r\nEv...
# 98  Time will bring you back to me\r\nIt always do...
# 99  Freight train, freight train, run so fast\r\nF...
#
#                        song  label                     ar_dash  \
# 90         Walking on Water  0.536             Eliza-Doolittle
# 91            Waste of Time  0.625             Eliza-Doolittle
# 92        Is It Like Today?  0.453              Eliza-Gilkyson
# 93          Beautiful World  0.366              Eliza-Gilkyson
# 94             Just in Time  0.138  Elizabeth-and-the-Catapult
# 95                   Apathy  0.312  Elizabeth-and-the-Catapult
# 96         Complimentary Me  0.422  Elizabeth-and-the-Catapult
# 97          Everybody Knows  0.258  Elizabeth-and-the-Catapult
# 98  Time (We All Fall Down)  0.696  Elizabeth-and-the-Catapult
# 99            Freight Train  0.489            Elizabeth-Cotten
#
#                    title_dash  \
# 90           Walking-on-Water
# 91              Waste-of-Time
# 92         Is-It-Like-Today-?
# 93            Beautiful-World
# 94               Just-in-Time
# 95                     Apathy
# 96           Complimentary-Me
# 97            Everybody-Knows
# 98  Time-(-We-All-Fall-Down-)
# 99              Freight-Train
#
#                                             song_path  \
# 90            Eliza-Doolittle-Walking-on-Water-lyrics
# 91               Eliza-Doolittle-Waste-of-Time-lyrics
# 92           Eliza-Gilkyson-Is-It-Like-Today-?-lyrics
# 93              Eliza-Gilkyson-Beautiful-World-lyrics
# 94     Elizabeth-and-the-Catapult-Just-in-Time-lyrics
# 95           Elizabeth-and-the-Catapult-Apathy-lyrics
# 96  Elizabeth-and-the-Catapult-Complimentary-Me-ly...
# 97  Elizabeth-and-the-Catapult-Everybody-Knows-lyrics
# 98  Elizabeth-and-the-Catapult-Time-(-We-All-Fall-...
# 99              Elizabeth-Cotten-Freight-Train-lyrics
#
#                                                   url
# 90  https://genius.com/Eliza-Doolittle-Walking-on-...
# 91  https://genius.com/Eliza-Doolittle-Waste-of-Ti...
# 92  https://genius.com/Eliza-Gilkyson-Is-It-Like-T...
# 93  https://genius.com/Eliza-Gilkyson-Beautiful-Wo...
# 94  https://genius.com/Elizabeth-and-the-Catapult-...
# 95  https://genius.com/Elizabeth-and-the-Catapult-...
# 96  https://genius.com/Elizabeth-and-the-Catapult-...
# 97  https://genius.com/Elizabeth-and-the-Catapult-...
# 98  https://genius.com/Elizabeth-and-the-Catapult-...
# 99  https://genius.com/Elizabeth-Cotten-Freight-Tr...

# %%
df_150kk = df_150k.iloc[0:100]

# %%
df_150kk
# Out:
#     Unnamed: 0                    artist  \
# 0            0              Elijah Blake
# 1            1              Elijah Blake
# 2            2              Elijah Blake
# 3            3              Elijah Blake
# 4            4              Elijah Blake
# ..         ...                       ...
# 95          95  Elizabeth & the Catapult
# 96          96  Elizabeth & the Catapult
# 97          97  Elizabeth & the Catapult
# 98          98  Elizabeth & the Catapult
# 99          99          Elizabeth Cotten
#
#                                                   seq  \
# 0   No, no\r\nI ain't ever trapped out the bando\r...
# 1   The drinks go down and smoke goes up, I feel m...
# 2   She don't live on planet Earth no more\r\nShe ...
# 3   Trippin' off that Grigio, mobbin', lights low\...
# 4   I see a midnight panther, so gallant and so br...
# ..                                                ...
# 95  Oh, Apathy\r\nDon't patronize me\r\nI wasn't s...
# 96  When I was girl I dreamed of my twin\r\nShe sh...
# 97  Everybody knows that the dice are loaded\r\nEv...
# 98  Time will bring you back to me\r\nIt always do...
# 99  Freight train, freight train, run so fast\r\nF...
#
#                        song  label                     ar_dash  \
# 0                  Everyday  0.626                Elijah-Blake
# 1          Live Till We Die  0.630                Elijah-Blake
# 2             The Otherside  0.240                Elijah-Blake
# 3                     Pinot  0.536                Elijah-Blake
# 4        Shadows & Diamonds  0.371                Elijah-Blake
# ..                      ...    ...                         ...
# 95                   Apathy  0.312  Elizabeth-and-the-Catapult
# 96         Complimentary Me  0.422  Elizabeth-and-the-Catapult
# 97          Everybody Knows  0.258  Elizabeth-and-the-Catapult
# 98  Time (We All Fall Down)  0.696  Elizabeth-and-the-Catapult
# 99            Freight Train  0.489            Elizabeth-Cotten
#
#                    title_dash  \
# 0                    Everyday
# 1            Live-Till-We-Die
# 2               The-Otherside
# 3                       Pinot
# 4        Shadows-and-Diamonds
# ..                        ...
# 95                     Apathy
# 96           Complimentary-Me
# 97            Everybody-Knows
# 98  Time-(-We-All-Fall-Down-)
# 99              Freight-Train
#
#                                             song_path  \
# 0                        Elijah-Blake-Everyday-lyrics
# 1                Elijah-Blake-Live-Till-We-Die-lyrics
# 2                   Elijah-Blake-The-Otherside-lyrics
# 3                           Elijah-Blake-Pinot-lyrics
# 4            Elijah-Blake-Shadows-and-Diamonds-lyrics
# ..                                                ...
# 95           Elizabeth-and-the-Catapult-Apathy-lyrics
# 96  Elizabeth-and-the-Catapult-Complimentary-Me-ly...
# 97  Elizabeth-and-the-Catapult-Everybody-Knows-lyrics
# 98  Elizabeth-and-the-Catapult-Time-(-We-All-Fall-...
# 99              Elizabeth-Cotten-Freight-Train-lyrics
#
#                                                   url
# 0     https://genius.com/Elijah-Blake-Everyday-lyrics
# 1   https://genius.com/Elijah-Blake-Live-Till-We-D...
# 2   https://genius.com/Elijah-Blake-The-Otherside-...
# 3        https://genius.com/Elijah-Blake-Pinot-lyrics
# 4   https://genius.com/Elijah-Blake-Shadows-and-Di...
# ..                                                ...
# 95  https://genius.com/Elizabeth-and-the-Catapult-...
# 96  https://genius.com/Elizabeth-and-the-Catapult-...
# 97  https://genius.com/Elizabeth-and-the-Catapult-...
# 98  https://genius.com/Elizabeth-and-the-Catapult-...
# 99  https://genius.com/Elizabeth-Cotten-Freight-Tr...
#
# [100 rows x 9 columns]

# %%
df_150kk['genre'].value_counts()
# Out:
# Pop          68
# No_genre     20
# Rap           5
# R&B           4
# Rock          1
# Non-Music     1
# Country       1
# Name: genre, dtype: int64

# %%
df_150kk['genre'].value_counts()

# %%
df_150kk['genre'] = df_150kk['url'].apply(get_genre)

# %%
for i in df_150kk['url']:
    print(i)
# Out:
# https://genius.com/Elijah-Blake-Everyday-lyrics
# https://genius.com/Elijah-Blake-Live-Till-We-Die-lyrics
# https://genius.com/Elijah-Blake-The-Otherside-lyrics
# https://genius.com/Elijah-Blake-Pinot-lyrics
# https://genius.com/Elijah-Blake-Shadows-and-Diamonds-lyrics
# https://genius.com/Elijah-Blake-Uno-lyrics
# https://genius.com/Elijah-Harris-Girlfriend-(-Main-)-lyrics
# https://genius.com/Elis-Abendlied-lyrics
# https://genius.com/Elis-Child-lyrics
# https://genius.com/Elis-Come-to-Me-lyrics
# https://genius.com/Elis-Do-You-Believe-lyrics
# https://genius.com/Elis-Engel-der-Nacht-lyrics
# https://genius.com/Elis-My-Only-Love-lyrics
# https://genius.com/Elis-Sie-Erfasst-Mein-Herz-lyrics
# https://genius.com/Elis-Anger-lyrics
# https://genius.com/Elis-Black-Angel-lyrics
# https://genius.com/Elis-Devil-Inside-You-lyrics
# https://genius.com/Elis-Heart-in-Chains-lyrics
# https://genius.com/Elis-Lost-Soul-lyrics
# https://genius.com/Elis-Perfect-Love-lyrics
# https://genius.com/Elis-Rebirth-lyrics
# https://genius.com/Elis-Brothers-lyrics
# https://genius.com/Elis-The-Burning-lyrics
# https://genius.com/Elis-Forgotten-Love-lyrics
# https://genius.com/Elis-Innocent-Hearts-lyrics
# https://genius.com/Elis-Phoenix-from-the-Ashes-lyrics
# https://genius.com/Elis-Remember-the-Promise-lyrics
# https://genius.com/Elis-Show-Me-the-Way-lyrics
# https://genius.com/Elis-I-Come-Undone-lyrics
# https://genius.com/Elis-Rainbow-lyrics
# https://genius.com/Elis-Regina-Fechado-Pra-Balanco-lyrics
# https://genius.com/Elis-Regina-Golden-Slumbers-lyrics
# https://genius.com/Elis-Regina-Gracias-a-la-Vida-lyrics
# https://genius.com/Elis-Regina-Triste-lyrics
# https://genius.com/Elis-Regina-Watch-What-Happens-lyrics
# https://genius.com/Elisa-Tell-Me-lyrics
# https://genius.com/Elisa-Tic-Tac-lyrics
# https://genius.com/Elisa-Fever-lyrics
# https://genius.com/Elisa-A-Little-Over-Zero-lyrics
# https://genius.com/Elisa-Femme-Fatale-lyrics
# https://genius.com/Elisa-Hallelujah-lyrics
# https://genius.com/Elisa-In-the-Green-lyrics
# https://genius.com/Elisa-Life-Goes-On-lyrics
# https://genius.com/Elisa-Together-lyrics
# https://genius.com/Elisa-Stay-lyrics
# https://genius.com/Elisa-Catch-the-Light-lyrics
# https://genius.com/Elisa-Love-Me-Forever-lyrics
# https://genius.com/Elisa-Peter-Pan-lyrics
# https://genius.com/Elisa-Ready-Now-lyrics
# https://genius.com/Elisa-Waste-Your-Time-on-Me-lyrics
# https://genius.com/Elisa-With-the-Hurt-lyrics
# https://genius.com/Elisabeth-Andreasson-Send-in-the-Clowns-lyrics
# https://genius.com/Elisabeth-Welch-Bye-Bye-Blackbird-lyrics
# https://genius.com/Elisabeth-Welch-It-Had-to-Be-You-lyrics
# https://genius.com/Elisabeth-Welch-The-Nearness-of-You-lyrics
# https://genius.com/Elisabeth-Welch-La-Vie-En-Rose-lyrics
# https://genius.com/Elisabeth-Withers-Be-with-You-lyrics
# https://genius.com/Elisabeth-Withers-Simple-Things-lyrics
# https://genius.com/Elissa-Back-to-Me-lyrics
# https://genius.com/Elissa-Without-You-lyrics
# https://genius.com/Elixer-For-the-First-Time-lyrics
# https://genius.com/Elixer-One-Sweet-Day-lyrics
# https://genius.com/Elixer-Eternal-Flame-lyrics
# https://genius.com/Eliza-Dream-Lover-lyrics
# https://genius.com/Eliza-In-My-Life-lyrics
# https://genius.com/Eliza-and-the-Bear-Thief-lyrics
# https://genius.com/Eliza-Carthy-Walk-Away-lyrics
# https://genius.com/Eliza-Carthy-The-Company-Of-Men-lyrics
# https://genius.com/Eliza-Carthy-Train-Song-lyrics
# https://genius.com/Eliza-Doolittle-Back-to-Front-lyrics
# https://genius.com/Eliza-Doolittle-Empty-Hand-lyrics
# https://genius.com/Eliza-Doolittle-Go-Home-lyrics
# https://genius.com/Eliza-Doolittle-Missing-lyrics
# https://genius.com/Eliza-Doolittle-Moneybox-lyrics
# https://genius.com/Eliza-Doolittle-Mr.-Medicine-lyrics
# https://genius.com/Eliza-Doolittle-Nobody-lyrics
# https://genius.com/Eliza-Doolittle-Police-Car-lyrics
# https://genius.com/Eliza-Doolittle-Rollerblades-lyrics
# https://genius.com/Eliza-Doolittle-A-Smokey-Room-lyrics
# https://genius.com/Eliza-Doolittle-So-High-lyrics
# https://genius.com/Eliza-Doolittle-Euston-Road-lyrics
# https://genius.com/Eliza-Doolittle-Back-Packing-lyrics
# https://genius.com/Eliza-Doolittle-Big-When-I-Was-Little-lyrics
# https://genius.com/Eliza-Doolittle-Checkmate-lyrics
# https://genius.com/Eliza-Doolittle-Hush-lyrics
# https://genius.com/Eliza-Doolittle-In-Your-Hands-lyrics
# https://genius.com/Eliza-Doolittle-Let-It-Rain-lyrics
# https://genius.com/Eliza-Doolittle-Make-Up-Sex-lyrics
# https://genius.com/Eliza-Doolittle-No-Man-Can-lyrics
# https://genius.com/Eliza-Doolittle-Team-Player-lyrics
# https://genius.com/Eliza-Doolittle-Walking-on-Water-lyrics
# https://genius.com/Eliza-Doolittle-Waste-of-Time-lyrics
# https://genius.com/Eliza-Gilkyson-Is-It-Like-Today-?-lyrics
# https://genius.com/Eliza-Gilkyson-Beautiful-World-lyrics
# https://genius.com/Elizabeth-and-the-Catapult-Just-in-Time-lyrics
# https://genius.com/Elizabeth-and-the-Catapult-Apathy-lyrics
# https://genius.com/Elizabeth-and-the-Catapult-Complimentary-Me-lyrics
# https://genius.com/Elizabeth-and-the-Catapult-Everybody-Knows-lyrics
# https://genius.com/Elizabeth-and-the-Catapult-Time-(-We-All-Fall-Down-)-lyrics
# https://genius.com/Elizabeth-Cotten-Freight-Train-lyrics

# %%
len(df_150k)
# Out:
# 158353

# %%
base_link = 'https://genius.com/'
df_150k['url'] = base_link + df_150k['song_path']

# %%
dff = df_150k.iloc[966:971]

# %%
for i in dff['url']:
    print(i)
    print(get_genre(i))
# Out:
# https://genius.com/Julia-Holter-Try-To-Make-Yourself-a-Work-of-Art-lyrics
# Pop
# https://genius.com/Julia-Holter-Feel-You-lyrics
# Pop
# https://genius.com/Julia-Holter-Everytime-Boots-lyrics
# Pop
# https://genius.com/Julia-Holter-Have-You-in-My-Wilderness-lyrics
# Pop
# https://genius.com/Julia-Holter-How-Long-?-lyrics
# No_genre

# %%
get_genre('https://genius.com/Ella-Fitzgerald-Dindi-lyrics')
# Out:
# Genre:  Pop

# %%
def get_genre(url):

    HEADERS = {'user-agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5)'
                          'AppleWebKit/537.36 (KHTML, like Gecko)'
                          'Chrome/45.0.2454.101 Safari/537.36'),
                          'referer': 'http://stats.nba.com/scores/'}
    
    source = re.get(url).text

    #soup object 
    soup = BeautifulSoup(source, 'lxml')

    #get the Genre class 
    tag_div = soup.find('div', class_='SongTags__Container-xixwg3-1 bZsZHM')
    
    #get the first genre from genre class
    try:
        tag_name = tag_div.a.text
        return tag_name
    except:
        return "No_genre";

# %%
158353/20
# Out:
# 7917.65

# %%
df_01 = df_150k.iloc[0:7917]

# %%
df_02 = df_150k.iloc[7917:(7917+7917)]

# %%
len(df_02)
# Out:
# 7917

# %%
df_02.head()
# Out:
#       Unnamed: 0       artist  \
# 7917        7917  Ray Anthony
# 7918        7918  Ray Anthony
# 7919        7919  Ray Anthony
# 7920        7920  Ray Anthony
# 7921        7921  Ray Anthony
#
#                                                     seq  \
# 7917  Can anyone explain the thrill of a kiss\r\nNo!...
# 7918  I knew the time had to come\r\nWhen I'd be hel...
# 7919  I know too well that I'm just wasting precious...
# 7920  I hadn't anyone till you,\r\nI was a lonely on...
# 7921  My love must be a kind of blind love\r\nI can'...
#
#                                      song  label      ar_dash  \
# 7917    Can Anyone Explain? (No, No, No!)  0.293  Ray-Anthony
# 7918  Nevertheless (I'm in Love with You)  0.518  Ray-Anthony
# 7919                         Easy to Love  0.509  Ray-Anthony
# 7920             I Hadn't Anyone Till You  0.171  Ray-Anthony
# 7921             I Only Have Eyes for You  0.123  Ray-Anthony
#
#                                    title_dash  \
# 7917  Can-Anyone-Explain-?-(-No-,-No-,-No-!-)
# 7918   Nevertheless-(-I-'m-in-Love-with-You-)
# 7919                             Easy-to-Love
# 7920                I-Had-n't-Anyone-Till-You
# 7921                 I-Only-Have-Eyes-for-You
#
#                                               song_path  \
# 7917  Ray-Anthony-Can-Anyone-Explain-?-(-No-,-No-,-N...
# 7918  Ray-Anthony-Nevertheless-(-I-'m-in-Love-with-Y...
# 7919                    Ray-Anthony-Easy-to-Love-lyrics
# 7920       Ray-Anthony-I-Had-n't-Anyone-Till-You-lyrics
# 7921        Ray-Anthony-I-Only-Have-Eyes-for-You-lyrics
#
#                                                     url
# 7917  https://genius.com/Ray-Anthony-Can-Anyone-Expl...
# 7918  https://genius.com/Ray-Anthony-Nevertheless-(-...
# 7919  https://genius.com/Ray-Anthony-Easy-to-Love-ly...
# 7920  https://genius.com/Ray-Anthony-I-Had-n't-Anyon...
# 7921  https://genius.com/Ray-Anthony-I-Only-Have-Eye...

# %%
df_03 = ""

# %%
df_03 = df_01.combine_first(df_02)

# %%
len(df_03)
# Out:
# 15834

# %%
df_04 = df_150k.iloc[(7917+7917):(7917+7917+10)]

# %%
df_03 = df_03.combine_first(df_04)

# %%
len(df_03)
# Out:
# 15844
